# %%
from IPython.display import Image

# %% [markdown]
# # WeRateDogs findings

# %% [markdown]
# ## Introduction
#
# WeRateDogs is a very popular Twitter channel (8.9 million followers) that rates dogs based on posted pictures. The comments are very funny and ratings are always 10+ out of 10.
#
# Because of the popularity of the channel and the number of posts it is a great database for data analysis.
#
# Based on gathered data I will try to answer three questions:
#
# 1. What is the most popular dog species (most tweets)?
# 2. Which dog species received the highest favorite count?
# 3. Is there a relation between favorite count and retweet count?

# %% [markdown]
# ## What is the most popular dog species (most tweets)?

# %% [markdown]
# Thanks to our image prediction neural network we were able to specify dog species. I was able to analyze around 2 000 tweets.
# Based on the data most popular dog species is Golden Retriever.

# %% [markdown]
# Below you can 10 most popular dog species based on the WeRateDogs Twitter account.

# %%
Image("picture03.png")

# %% [markdown]
# ## Which dog species received the highest favorite count?

# %% [markdown]
# Next, I wanted to check if Golden Retriever is also the species with the highest favorite count tweet. Based on the data below Labrador Retriever is the species with the highest favorite count. As we can see it's the second most popular dog species.

# %%
Image("picture04.png")

# %% [markdown]
# Below we can see the picture of the dog in question ;)

# %%
Image("https://pbs.twimg.com/ext_tw_video_thumb/744234667679821824/pu/img/1GaWmtJtdqzZV7jy.jpg")

# %% [markdown]
# ## Is there is a relation between favorite count and retweet count?

# %% [markdown]
# For the last question I wanted to see if there is a relation between favorite count and retweet count. My gut says there is - however, I wanted to check if a hypothesis is true that people retweet posts because they like them.

# %% [markdown]
# Based on the graph below we can see a positive relation between favorite count and retweet count.
# So YES people retweet posts that they like :)

# %%
Image("picture05.png")
